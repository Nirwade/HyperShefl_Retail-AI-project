# %%
# test_agent.py — run this after Ollama is running
import sys
sys.path.insert(0, "/Users/shashi/retail-ai-project")

from src.agent import DemandSenseAgent

# Test 1 — store manager persona
agent = DemandSenseAgent(persona="store_manager")
result = agent.chat("What are the top phantom alerts at store S0001?")
print(result["response"])
print("Tools called:", [t["tool"] for t in result["tool_calls_made"]])

# Test 2 — supply chain persona
agent2 = DemandSenseAgent(persona="supply_chain_planner")
result2 = agent2.chat("What is the stockout risk for SKU P01255 at store S0430?")
print(result2["response"])
# Out:
# [ModelRegistry] Loading all model artifacts...
# [ModelRegistry] Loading pre-computed outputs...
# [ModelRegistry] Ready — 3,271,439 prediction rows · 3,271,439 replenishment rows
# [Agent] DemandSenseAgent ready — persona: store_manager · model: llama3.1:8b
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 9
#       7 # Test 1 — store manager persona
#       8 agent = DemandSenseAgent(persona="store_manager")
# ----> 9 result = agent.chat("What are the top phantom alerts at store S0001?")
#      10 print(result["response"])
#      11 print("Tools called:", [t["tool"] for t in result["tool_calls_made"]])
#
# File ~/retail-ai-project/src/agent.py:52, in DemandSenseAgent.chat(self, user_message)
#      49 escalation_reason = None
#      51 # ── First call — let model decide which tool to call ──────
# ---> 52 response = ollama.chat(
# ...
