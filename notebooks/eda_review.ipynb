# %% [markdown]
# What MAPE/MAE target should we aim for ?
# High-volume staples: target MAPE < 15%
# Volatile/seasonal items: target MAPE < 30%
# Niche items: target MAPE < 50%
# Is 48.68% MAPE acceptable?
# What's the cost of 1-unit error?

# %% [markdown]
#  Should we forecast by FOOT TRAFFIC TIER instead of considering all stores
#    → Could improve MAPE by 15-20%
#
#  we can segment forecasts by Store Format + Foot Traffic
#     Premium Supermarket vs Low Discount = very different
#     can we impliment tier cap = {"Low": 5, "Medium": 10, "High": 15, "Premium": 25}
#
#  Some categories need better forecasting
#    → Beverages (32M units) = highest priority
#    → Health & Wellness (11M units) = lower priority

# %% [markdown]
#  How often do you promote each category? (weekly, monthly, quarterly?)
#   Does promotion lift vary by store type? (Premium stores vs Low traffic stores?)
# : Do you have safety stock levels? Example: Canned & Pantry = minimum 20 units always in stock?
#  Do you have inventory targets by category? Example: Canned & Pantry = 500 units target?
